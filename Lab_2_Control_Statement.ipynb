# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest:", a)
elif b > c:
    print("Largest:", b)
else:
    print("Largest:", c)

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

op = input("Enter operator (+, -, *, /): ")

if op == '+':
    print("Result:", a + b)
elif op == '-':
    print("Result:", a - b)
elif op == '*':
    print("Result:", a * b)
elif op == '/':
    if b != 0:
        print("Result:", a / b)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")

# %%
for i in range(1, 11):
    print(i)

# %%
i = 1
while i <= 5:
    print(i)
    i += 1

# %%
i = 1
while True:
    print(i)
    i += 1
    if i > 5:
        break

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)

# %% [markdown]
# Conclusion
#
# Control statements help a program make decisions and repeat tasks efficiently. In this lab, we used conditions and loops to solve problems like checking numbers, performing calculations, and generating tables. These concepts are essential for building logical and interactive programs.
